# %% [markdown]
# # 01. FastAPI 서버 구축
#
# * Conda 가상환경 활성화
# * Uvicorn 설치 (Spring 의 내장 Tomcat 역할)
#
# step 01
# * pip install fastapi uvicorn
#
# step 02
# * uvicorn main:app --reload
# * uvicorn : FastAPI Application을 실행하는 Server == Spring Tomcat
# * main : main.py 파일을 지칭한다.
# * app : main.py 내부애 존재하는 FastAPI 객체 변수명
